# %%
import pandas as pd
import numpy as np

# %%
#Loading Data
data = pd.read_csv("C:/Users/student/Downloads/archive (4)/ai_job_dataset.csv")
data
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 0      AI00001        AI Research Scientist       90376             USD
# 1      AI00002         AI Software Engineer       61895             USD
# 2      AI00003                AI Specialist      152626             USD
# 3      AI00004                 NLP Engineer       80215             USD
# 4      AI00005                AI Consultant       54624             EUR
# ...        ...                          ...         ...             ...
# 14995  AI14996            Robotics Engineer       38604             USD
# 14996  AI14997  Machine Learning Researcher       57811             GBP
# 14997  AI14998                 NLP Engineer      189490             USD
# 14998  AI14999                   Head of AI       79461             EUR
# 14999  AI15000     Computer Vision Engineer       56481             USD
#
#       experience_level employment_type company_location company_size  \
# 0                   SE              CT            China            M
# 1                   EN              CT           Canada            M
# 2                   MI              FL      Switzerland            L
# 3                   SE              FL            India            M
# 4                   EN              PT           France            S
# ...                ...             ...              ...          ...
# 14995               EN              FL          Finland            S
# 14996               EN              CT   United Kingdom            M
# 14997               EX              CT      South Korea            L
# 14998               EN              FT      Netherlands            M
# 14999               MI              PT          Austria            S
#
#       employee_residence  remote_ratio  \
# 0                  China            50
# 1                Ireland           100
# 2            South Korea             0
# 3                  India            50
# 4              Singapore           100
# ...                  ...           ...
# 14995            Finland            50
# 14996     United Kingdom             0
# 14997        South Korea            50
# 14998        Netherlands             0
# 14999            Austria            50
#
#                                        required_skills education_required  \
# 0             Tableau, PyTorch, Kubernetes, Linux, NLP           Bachelor
# 1      Deep Learning, AWS, Mathematics, Python, Docker             Master
# 2         Kubernetes, Deep Learning, Java, Hadoop, NLP          Associate
# 3                            Scala, SQL, Linux, Python                PhD
# 4                         MLOps, Java, Tableau, Python             Master
# ...                                                ...                ...
# 14995                          Java, Kubernetes, Azure           Bachelor
# 14996          Mathematics, Docker, SQL, Deep Learning             Master
# 14997                                Scala, Spark, NLP          Associate
# 14998        Java, Computer Vision, Python, TensorFlow                PhD
# 14999    Scala, Azure, Deep Learning, GCP, Mathematics                PhD
#
#        years_experience       industry posting_date application_deadline  \
# 0                     9     Automotive   2024-10-18           2024-11-07
# 1                     1          Media   2024-11-20           2025-01-11
# 2                     2      Education   2025-03-18           2025-04-07
# 3                     7     Consulting   2024-12-23           2025-02-24
# 4                     0          Media   2025-04-15           2025-06-23
# ...                 ...            ...          ...                  ...
# 14995                 1         Energy   2025-02-06           2025-03-25
# 14996                 0     Government   2024-10-16           2024-10-30
# 14997                17  Manufacturing   2024-03-19           2024-05-02
# 14998                 1    Real Estate   2024-03-22           2024-04-23
# 14999                 2     Technology   2024-07-18           2024-08-10
#
#        job_description_length  benefits_score       company_name
# 0                        1076             5.9    Smart Analytics
# 1                        1268             5.2       TechCorp Inc
# 2                        1974             9.4    Autonomous Tech
# 3                        1345             8.6     Future Systems
# 4                        1989             6.6  Advanced Robotics
# ...                       ...             ...                ...
# 14995                    1635             7.9  Advanced Robotics
# 14996                    1624             8.2    Smart Analytics
# 14997                    1336             7.4     AI Innovations
# 14998                    1935             5.6    Smart Analytics
# 14999                    2492             7.6     AI Innovations
#
# [15000 rows x 19 columns]

# %%
#Summary of DataFrame
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   job_id                  15000 non-null  object
#  1   job_title               15000 non-null  object
#  2   salary_usd              15000 non-null  int64
#  3   salary_currency         15000 non-null  object
#  4   experience_level        15000 non-null  object
#  5   employment_type         15000 non-null  object
#  6   company_location        15000 non-null  object
#  7   company_size            15000 non-null  object
#  8   employee_residence      15000 non-null  object
#  9   remote_ratio            15000 non-null  int64
#  10  required_skills         15000 non-null  object
#  11  education_required      15000 non-null  object
#  12  years_experience        15000 non-null  int64
#  13  industry                15000 non-null  object
#  14  posting_date            15000 non-null  object
#  15  application_deadline    15000 non-null  object
#  16  job_description_length  15000 non-null  int64
#  17  benefits_score          15000 non-null  float64
#  18  company_name            15000 non-null  object
# dtypes: float64(1), int64(4), object(14)
# memory usage: 2.2+ MB

# %%
#Dimentions of the DataFrame
data.shape
# Out:
# (15000, 19)

# %%
#List of all column names
list(data.columns)
# Out:
# ['job_id',
#  'job_title',
#  'salary_usd',
#  'salary_currency',
#  'experience_level',
#  'employment_type',
#  'company_location',
#  'company_size',
#  'employee_residence',
#  'remote_ratio',
#  'required_skills',
#  'education_required',
#  'years_experience',
#  'industry',
#  'posting_date',
#  'application_deadline',
#  'job_description_length',
#  'benefits_score',
#  'company_name']

# %%
#First 5 rows of the DataFrame
data.head()
# Out:
#     job_id              job_title  salary_usd salary_currency  \
# 0  AI00001  AI Research Scientist       90376             USD
# 1  AI00002   AI Software Engineer       61895             USD
# 2  AI00003          AI Specialist      152626             USD
# 3  AI00004           NLP Engineer       80215             USD
# 4  AI00005          AI Consultant       54624             EUR
#
#   experience_level employment_type company_location company_size  \
# 0               SE              CT            China            M
# 1               EN              CT           Canada            M
# 2               MI              FL      Switzerland            L
# 3               SE              FL            India            M
# 4               EN              PT           France            S
#
#   employee_residence  remote_ratio  \
# 0              China            50
# 1            Ireland           100
# 2        South Korea             0
# 3              India            50
# 4          Singapore           100
#
#                                    required_skills education_required  \
# 0         Tableau, PyTorch, Kubernetes, Linux, NLP           Bachelor
# 1  Deep Learning, AWS, Mathematics, Python, Docker             Master
# 2     Kubernetes, Deep Learning, Java, Hadoop, NLP          Associate
# 3                        Scala, SQL, Linux, Python                PhD
# 4                     MLOps, Java, Tableau, Python             Master
#
#    years_experience    industry posting_date application_deadline  \
# 0                 9  Automotive   2024-10-18           2024-11-07
# 1                 1       Media   2024-11-20           2025-01-11
# 2                 2   Education   2025-03-18           2025-04-07
# 3                 7  Consulting   2024-12-23           2025-02-24
# 4                 0       Media   2025-04-15           2025-06-23
#
#    job_description_length  benefits_score       company_name
# 0                    1076             5.9    Smart Analytics
# 1                    1268             5.2       TechCorp Inc
# 2                    1974             9.4    Autonomous Tech
# 3                    1345             8.6     Future Systems
# 4                    1989             6.6  Advanced Robotics

# %%
#Last 5 rows of the DataFrame
data.tail()
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 14995  AI14996            Robotics Engineer       38604             USD
# 14996  AI14997  Machine Learning Researcher       57811             GBP
# 14997  AI14998                 NLP Engineer      189490             USD
# 14998  AI14999                   Head of AI       79461             EUR
# 14999  AI15000     Computer Vision Engineer       56481             USD
#
#       experience_level employment_type company_location company_size  \
# 14995               EN              FL          Finland            S
# 14996               EN              CT   United Kingdom            M
# 14997               EX              CT      South Korea            L
# 14998               EN              FT      Netherlands            M
# 14999               MI              PT          Austria            S
#
#       employee_residence  remote_ratio  \
# 14995            Finland            50
# 14996     United Kingdom             0
# 14997        South Korea            50
# 14998        Netherlands             0
# 14999            Austria            50
#
#                                      required_skills education_required  \
# 14995                        Java, Kubernetes, Azure           Bachelor
# 14996        Mathematics, Docker, SQL, Deep Learning             Master
# 14997                              Scala, Spark, NLP          Associate
# 14998      Java, Computer Vision, Python, TensorFlow                PhD
# 14999  Scala, Azure, Deep Learning, GCP, Mathematics                PhD
#
#        years_experience       industry posting_date application_deadline  \
# 14995                 1         Energy   2025-02-06           2025-03-25
# 14996                 0     Government   2024-10-16           2024-10-30
# 14997                17  Manufacturing   2024-03-19           2024-05-02
# 14998                 1    Real Estate   2024-03-22           2024-04-23
# 14999                 2     Technology   2024-07-18           2024-08-10
#
#        job_description_length  benefits_score       company_name
# 14995                    1635             7.9  Advanced Robotics
# 14996                    1624             8.2    Smart Analytics
# 14997                    1336             7.4     AI Innovations
# 14998                    1935             5.6    Smart Analytics
# 14999                    2492             7.6     AI Innovations

# %%
#Summary statistics
data.describe()
# Out:
#           salary_usd  remote_ratio  years_experience  job_description_length  \
# count   15000.000000  15000.000000      15000.000000            15000.000000
# mean   115348.965133     49.483333          6.253200             1503.314733
# std     60260.940438     40.812712          5.545768              576.127083
# min     32519.000000      0.000000          0.000000              500.000000
# 25%     70179.750000      0.000000          2.000000             1003.750000
# 50%     99705.000000     50.000000          5.000000             1512.000000
# 75%    146408.500000    100.000000         10.000000             2000.000000
# max    399095.000000    100.000000         19.000000             2499.000000
#
#        benefits_score
# count    15000.000000
# mean         7.504273
# std          1.450870
# min          5.000000
# 25%          6.200000
# 50%          7.500000
# 75%          8.800000
# max         10.000000

# %%
#Summary statistics of objects(non-numerical columns)
data.describe(include="O")
# Out:
#          job_id                    job_title salary_currency experience_level  \
# count     15000                        15000           15000            15000
# unique    15000                           20               3                4
# top     AI00001  Machine Learning Researcher             USD               MI
# freq          1                          808           11957             3781
#
#        employment_type company_location company_size employee_residence  \
# count            15000            15000        15000              15000
# unique               4               20            3                 20
# top                 FT          Germany            S             Sweden
# freq              3812              814         5007                790
#
#                     required_skills education_required industry posting_date  \
# count                         15000              15000    15000        15000
# unique                        13663                  4       15          486
# top     Python, TensorFlow, PyTorch           Bachelor   Retail   2024-07-05
# freq                             17               3789     1063           51
#
#        application_deadline  company_name
# count                 15000         15000
# unique                  543            16
# top              2025-01-05  TechCorp Inc
# freq                     47           980

# %%
#Number of unique job titles 
data["job_title"].value_counts().to_frame()
# Out:
#                              count
# job_title
# Machine Learning Researcher    808
# AI Software Engineer           784
# Autonomous Systems Engineer    777
# Machine Learning Engineer      772
# AI Architect                   771
# Head of AI                     765
# NLP Engineer                   762
# Robotics Engineer              759
# Data Analyst                   759
# AI Research Scientist          756
# Data Engineer                  749
# AI Product Manager             743
# Research Scientist             742
# Principal Data Scientist       734
# AI Specialist                  728
# ML Ops Engineer                725
# Computer Vision Engineer       724
# Data Scientist                 720
# Deep Learning Engineer         718
# AI Consultant                  704

# %%
# Number of occurances of each unique employment type
data["employment_type"].value_counts().to_frame()
# Out:
#                  count
# employment_type
# FT                3812
# FL                3758
# CT                3721
# PT                3709

# %%
# Counts how many companies fall into each company size category
data["company_size"].value_counts().to_frame()
# Out:
#               count
# company_size
# S              5007
# L              4998
# M              4995

# %%
#Number of times each company appears
data["company_name"].value_counts().to_frame()
# Out:
#                             count
# company_name
# TechCorp Inc                  980
# Cognitive Computing           972
# AI Innovations                964
# Digital Transformation LLC    961
# Future Systems                960
# Quantum Computing Inc         960
# Cloud AI Solutions            951
# Predictive Systems            947
# Smart Analytics               927
# Advanced Robotics             925
# Neural Networks Co            922
# Machine Intelligence Group    922
# Autonomous Tech               918
# DataVision Ltd                909
# DeepTech Ventures             897
# Algorithmic Solutions         885

# %%
#All unique values in USD
data["salary_usd"].unique()
# Out:
# array([ 90376,  61895, 152626, ..., 189490,  79461,  56481], dtype=int64)

# %%
#All unique values in Benifits score
data["benefits_score"].unique()
# Out:
# array([ 5.9,  5.2,  9.4,  8.6,  6.6,  6.3,  7.6,  9.3,  5.8,  9.9,  6.8,
#         9.1,  9.8,  9.6,  8.7,  6.7, 10. ,  6.9,  7.4,  8.8,  7.7,  6. ,
#         9.2,  5.3,  5.7,  7.9,  6.1,  8.1,  8. ,  5.1,  7.5,  5.5,  5.4,
#         9.7,  7.2,  5.6,  9. ,  6.2,  6.5,  7.1,  9.5,  7. ,  8.2,  8.4,
#         7.8,  6.4,  8.3,  8.9,  7.3,  8.5,  5. ])

# %%
#Checking for Duplicate Entries
data.duplicated().sum()
# Out:
# 0

# %%
#Checking for missing values
data.isnull().sum().to_frame()
# Out:
#                         0
# job_id                  0
# job_title               0
# salary_usd              0
# salary_currency         0
# experience_level        0
# employment_type         0
# company_location        0
# company_size            0
# employee_residence      0
# remote_ratio            0
# required_skills         0
# education_required      0
# years_experience        0
# industry                0
# posting_date            0
# application_deadline    0
# job_description_length  0
# benefits_score          0
# company_name            0

# %%
#Selecting rows 50 to 60 of salary in USD column and converting into a DataFrame
data.loc[50:60 ,"salary_usd"].to_frame()
# Out:
#     salary_usd
# 50       70391
# 51      115376
# 52      106579
# 53      135230
# 54       67607
# 55       88470
# 56       79863
# 57       60299
# 58       85645
# 59      110222
# 60       49365

# %%
#selects rows 50 to 59 of the 5th column (index 4) using integer location based indexing and converts the result into a DataFrame
data.iloc[50:60 ,4].to_frame()
# Out:
#    experience_level
# 50               MI
# 51               EX
# 52               MI
# 53               SE
# 54               MI
# 55               MI
# 56               MI
# 57               EN
# 58               MI
# 59               SE

# %%
#Summary statistic for USD salary
data[["salary_usd"]].agg(["max","mean","min"])
# Out:
#          salary_usd
# max   399095.000000
# mean  115348.965133
# min    32519.000000

# %%
#DataFrame filtered to show only rows where salary_usd equals 399,095
data[data["salary_usd"] == 	399095.000000]
# Out:
#        job_id                    job_title  salary_usd salary_currency  \
# 9891  AI09892  Machine Learning Researcher      399095             USD
#
#      experience_level employment_type company_location company_size  \
# 9891               EX              PT      Switzerland            L
#
#      employee_residence  remote_ratio            required_skills  \
# 9891        Switzerland             0  Linux, Python, TensorFlow
#
#      education_required  years_experience industry posting_date  \
# 9891             Master                10   Retail   2024-07-10
#
#      application_deadline  job_description_length  benefits_score  \
# 9891           2024-09-02                    2277             9.7
#
#       company_name
# 9891  TechCorp Inc

# %%
#Summary statistic for benifits score
data[["benefits_score"]].agg(["max","mean","min"])
# Out:
#       benefits_score
# max        10.000000
# mean        7.504273
# min         5.000000

# %%
#Filters DataFrame to return only rows where benifits_score is equal to 5
data[data["benefits_score"] == 5]
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 192    AI00193              ML Ops Engineer      134300             USD
# 282    AI00283                 NLP Engineer      199482             EUR
# 332    AI00333                 NLP Engineer       44279             USD
# 339    AI00340               Data Scientist       99604             USD
# 510    AI00511                AI Specialist      156725             USD
# ...        ...                          ...         ...             ...
# 14690  AI14691  Autonomous Systems Engineer      157067             USD
# 14711  AI14712               Data Scientist       79555             USD
# 14724  AI14725                 NLP Engineer       59192             USD
# 14828  AI14829                 Data Analyst       39506             USD
# 14973  AI14974           AI Product Manager       78429             USD
#
#       experience_level employment_type company_location company_size  \
# 192                 EX              CT          Ireland            S
# 282                 EX              PT           France            S
# 332                 EN              CT           Israel            S
# 339                 EX              PT            Japan            S
# 510                 EX              CT      South Korea            L
# ...                ...             ...              ...          ...
# 14690               SE              FT           Norway            S
# 14711               EN              FT        Singapore            L
# 14724               EN              CT          Ireland            L
# 14828               EN              FL           Israel            S
# 14973               MI              PT        Singapore            S
#
#       employee_residence  remote_ratio  \
# 192              Ireland            50
# 282               France            50
# 332              Austria             0
# 339                Japan            50
# 510               Sweden             0
# ...                  ...           ...
# 14690             Norway            50
# 14711        Netherlands             0
# 14724            Ireland           100
# 14828             France             0
# 14973          Singapore             0
#
#                                          required_skills education_required  \
# 192              Java, Python, Deep Learning, Statistics             Master
# 282                             PyTorch, Scala, NLP, GCP           Bachelor
# 332    Tableau, Linux, Java, Kubernetes, Computer Vision                PhD
# 339                          PyTorch, Mathematics, Linux             Master
# 510                                 AWS, Kubernetes, NLP          Associate
# ...                                                  ...                ...
# 14690      Spark, TensorFlow, Python, Data Visualization             Master
# 14711                Python, NLP, Azure, Computer Vision             Master
# 14724                       MLOps, Data Visualization, R                PhD
# 14828                          Linux, Docker, TensorFlow          Associate
# 14973                        SQL, Kubernetes, TensorFlow           Bachelor
#
#        years_experience        industry posting_date application_deadline  \
# 192                  11       Education   2024-07-14           2024-09-16
# 282                  18  Transportation   2025-02-17           2025-04-30
# 332                   1      Technology   2024-05-02           2024-07-13
# 339                  11       Education   2024-01-04           2024-02-24
# 510                  19           Media   2024-07-13           2024-09-02
# ...                 ...             ...          ...                  ...
# 14690                 9         Finance   2024-11-15           2024-12-13
# 14711                 1   Manufacturing   2025-03-03           2025-04-12
# 14724                 1  Transportation   2024-08-30           2024-10-24
# 14828                 1          Gaming   2024-04-20           2024-05-27
# 14973                 4          Gaming   2024-04-02           2024-06-05
#
#        job_description_length  benefits_score                company_name
# 192                      2111             5.0          Predictive Systems
# 282                      1230             5.0                TechCorp Inc
# 332                       539             5.0       Algorithmic Solutions
# 339                       849             5.0             Smart Analytics
# 510                      1293             5.0           Advanced Robotics
# ...                       ...             ...                         ...
# 14690                    1546             5.0             Autonomous Tech
# 14711                     717             5.0  Digital Transformation LLC
# 14724                    1897             5.0  Digital Transformation LLC
# 14828                    2444             5.0          Cloud AI Solutions
# 14973                    2015             5.0              AI Innovations
#
# [139 rows x 19 columns]

# %%
#Summary statistic for Job length
data[["job_description_length"]].agg(["max","mean","min"])
# Out:
#       job_description_length
# max              2499.000000
# mean             1503.314733
# min               500.000000

# %%
#Filters DataFrame to return only rows where job_description_length is equal to 2499 
data[data["job_description_length"] == 2499]
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 1123   AI01124                   Head of AI       83896             USD
# 2054   AI02055  Machine Learning Researcher      230705             USD
# 2782   AI02783  Autonomous Systems Engineer       51501             USD
# 3331   AI03332           AI Product Manager      114659             EUR
# 3386   AI03387                AI Consultant       96345             USD
# 7089   AI07090                   Head of AI       63549             EUR
# 12736  AI12737     Principal Data Scientist       68443             USD
#
#       experience_level employment_type company_location company_size  \
# 1123                SE              CT      South Korea            L
# 2054                EX              CT           Canada            M
# 2782                EN              FT        Australia            M
# 3331                MI              PT           France            L
# 3386                SE              CT            Japan            L
# 7089                EN              FT          Germany            M
# 12736               EN              CT      Switzerland            S
#
#       employee_residence  remote_ratio  \
# 1123         South Korea           100
# 2054              Canada           100
# 2782           Australia           100
# 3331              France             0
# 3386           Singapore            50
# 7089             Germany            50
# 12736            Finland            50
#
#                                          required_skills education_required  \
# 1123              Data Visualization, Docker, MLOps, Git          Associate
# 2054         Linux, Mathematics, Python, Git, Statistics          Associate
# 2782   Computer Vision, TensorFlow, Mathematics, SQL,...                PhD
# 3331                         R, Scala, Git, GCP, Tableau             Master
# 3386                                      R, NLP, Python           Bachelor
# 7089                                  Git, R, TensorFlow           Bachelor
# 12736                          Mathematics, Java, Hadoop           Bachelor
#
#        years_experience            industry posting_date application_deadline  \
# 1123                  9       Manufacturing   2024-08-19           2024-09-14
# 2054                 11          Automotive   2024-01-21           2024-03-09
# 2782                  1              Energy   2025-03-22           2025-05-10
# 3331                  3  Telecommunications   2024-07-08           2024-07-29
# 3386                  6         Real Estate   2024-11-02           2024-11-19
# 7089                  1           Education   2024-11-25           2025-02-03
# 12736                 1              Gaming   2024-04-23           2024-05-28
#
#        job_description_length  benefits_score                company_name
# 1123                     2499             5.9          Predictive Systems
# 2054                     2499             5.8          Cloud AI Solutions
# 2782                     2499             8.6          Cloud AI Solutions
# 3331                     2499             7.2          Cloud AI Solutions
# 3386                     2499             5.3       Algorithmic Solutions
# 7089                     2499             9.9              AI Innovations
# 12736                    2499             6.1  Machine Intelligence Group

# %%
#counts how many records exist for each employee residence–company location combination
data.groupby("employee_residence")["company_location"].size().to_frame().reset_index()
# Out:
#    employee_residence  company_location
# 0           Australia               730
# 1             Austria               776
# 2              Canada               762
# 3               China               761
# 4             Denmark               777
# 5             Finland               710
# 6              France               781
# 7             Germany               769
# 8               India               772
# 9             Ireland               740
# 10             Israel               731
# 11              Japan               700
# 12        Netherlands               758
# 13             Norway               726
# 14          Singapore               740
# 15        South Korea               763
# 16             Sweden               790
# 17        Switzerland               748
# 18     United Kingdom               750
# 19      United States               716

# %%
#groups the data by employee residence, company location, and company size. shows how many jobs and the average salary for each residence–location–company size combination.
company_size_analysis = data.groupby(['employee_residence', 'company_location', 'company_size']).agg({
    'job_id': 'count',
    'salary_usd': 'mean'
}).reset_index()
company_size_analysis
# Out:
#      employee_residence company_location company_size  job_id     salary_usd
# 0             Australia        Australia            L     174  139881.344828
# 1             Australia        Australia            M     177  114206.649718
# 2             Australia        Australia            S     177  103915.689266
# 3             Australia          Austria            L       5  124024.600000
# 4             Australia          Austria            M       3   62957.333333
# ...                 ...              ...          ...     ...            ...
# 1171      United States   United Kingdom            M       1  113568.000000
# 1172      United States   United Kingdom            S       3  135871.333333
# 1173      United States    United States            L     175  161007.462857
# 1174      United States    United States            M     169  144004.781065
# 1175      United States    United States            S     159  129737.088050
#
# [1176 rows x 5 columns]

# %%
#groups the data by education level, employment type, and years of experience. result is a DataFrame showing how job count and maximum salary vary by education, employment type, and experience level.
salary_employment_type = data.groupby(["education_required","employment_type","years_experience"]).agg({
    "job_id": "count",
    "salary_usd": "max"
}).reset_index()

salary_employment_type
# Out:
#     education_required employment_type  years_experience  job_id  salary_usd
# 0            Associate              CT                 0     113      124467
# 1            Associate              CT                 1     129      116790
# 2            Associate              CT                 2      91      156540
# 3            Associate              CT                 3      63      173822
# 4            Associate              CT                 4      86      162750
# ..                 ...             ...               ...     ...         ...
# 315                PhD              PT                15      26      316492
# 316                PhD              PT                16      22      304214
# 317                PhD              PT                17      23      344427
# 318                PhD              PT                18      18      309048
# 319                PhD              PT                19      26      279728
#
# [320 rows x 5 columns]

# %%
#finds the highest salary for each experience level
data.groupby("experience_level") ["salary_usd"].max().to_frame().sort_values( by = "salary_usd" , ascending = False )
# Out:
#                   salary_usd
# experience_level
# EX                    399095
# SE                    247271
# MI                    177470
# EN                    131006

# %%
#finds the highest salary for each job title
data.groupby("job_title") ["salary_usd"].max().to_frame().sort_values( by = "salary_usd" , ascending = False )
# Out:
#                              salary_usd
# job_title
# Machine Learning Researcher      399095
# AI Architect                     398084
# AI Research Scientist            394917
# AI Specialist                    390292
# Data Scientist                   388754
# AI Product Manager               381575
# AI Software Engineer             379418
# Computer Vision Engineer         366957
# Principal Data Scientist         364635
# Autonomous Systems Engineer      364585
# Deep Learning Engineer           362503
# Head of AI                       361718
# Data Analyst                     361541
# Data Engineer                    359044
# NLP Engineer                     357880
# ML Ops Engineer                  352006
# Robotics Engineer                346789
# Machine Learning Engineer        344427
# Research Scientist               339526
# AI Consultant                    325757

# %%
#finds the highest salary for each company
data.groupby("company_name") ["salary_usd"].max().to_frame().sort_values( by = "salary_usd" , ascending = False )
# Out:
#                             salary_usd
# company_name
# TechCorp Inc                    399095
# Future Systems                  398084
# Machine Intelligence Group      394917
# DataVision Ltd                  390292
# DeepTech Ventures               388754
# Neural Networks Co              381575
# Algorithmic Solutions           379418
# Quantum Computing Inc           372206
# Digital Transformation LLC      364635
# Cloud AI Solutions              364585
# Advanced Robotics               361723
# Autonomous Tech                 353055
# Predictive Systems              350616
# Smart Analytics                 349508
# Cognitive Computing             341883
# AI Innovations                  337306

# %%
# groups data by posting date
data.groupby("posting_date")["application_deadline"].max().to_frame().reset_index()
# Out:
#     posting_date application_deadline
# 0     2024-01-01           2024-03-13
# 1     2024-01-02           2024-03-14
# 2     2024-01-03           2024-03-14
# 3     2024-01-04           2024-03-17
# 4     2024-01-05           2024-03-18
# ..           ...                  ...
# 481   2025-04-26           2025-07-08
# 482   2025-04-27           2025-07-09
# 483   2025-04-28           2025-07-10
# 484   2025-04-29           2025-07-09
# 485   2025-04-30           2025-07-11
#
# [486 rows x 2 columns]

# %%
import matplotlib.pyplot as plt #basic plotting function
import seaborn as sns # higher level stats visualizations
import warnings
warnings.filterwarnings('ignore')

# %%
data
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 0      AI00001        AI Research Scientist       90376             USD
# 1      AI00002         AI Software Engineer       61895             USD
# 2      AI00003                AI Specialist      152626             USD
# 3      AI00004                 NLP Engineer       80215             USD
# 4      AI00005                AI Consultant       54624             EUR
# ...        ...                          ...         ...             ...
# 14995  AI14996            Robotics Engineer       38604             USD
# 14996  AI14997  Machine Learning Researcher       57811             GBP
# 14997  AI14998                 NLP Engineer      189490             USD
# 14998  AI14999                   Head of AI       79461             EUR
# 14999  AI15000     Computer Vision Engineer       56481             USD
#
#       experience_level employment_type company_location company_size  \
# 0                   SE              CT            China            M
# 1                   EN              CT           Canada            M
# 2                   MI              FL      Switzerland            L
# 3                   SE              FL            India            M
# 4                   EN              PT           France            S
# ...                ...             ...              ...          ...
# 14995               EN              FL          Finland            S
# 14996               EN              CT   United Kingdom            M
# 14997               EX              CT      South Korea            L
# 14998               EN              FT      Netherlands            M
# 14999               MI              PT          Austria            S
#
#       employee_residence  remote_ratio  \
# 0                  China            50
# 1                Ireland           100
# 2            South Korea             0
# 3                  India            50
# 4              Singapore           100
# ...                  ...           ...
# 14995            Finland            50
# 14996     United Kingdom             0
# 14997        South Korea            50
# 14998        Netherlands             0
# 14999            Austria            50
#
#                                        required_skills education_required  \
# 0             Tableau, PyTorch, Kubernetes, Linux, NLP           Bachelor
# 1      Deep Learning, AWS, Mathematics, Python, Docker             Master
# 2         Kubernetes, Deep Learning, Java, Hadoop, NLP          Associate
# 3                            Scala, SQL, Linux, Python                PhD
# 4                         MLOps, Java, Tableau, Python             Master
# ...                                                ...                ...
# 14995                          Java, Kubernetes, Azure           Bachelor
# 14996          Mathematics, Docker, SQL, Deep Learning             Master
# 14997                                Scala, Spark, NLP          Associate
# 14998        Java, Computer Vision, Python, TensorFlow                PhD
# 14999    Scala, Azure, Deep Learning, GCP, Mathematics                PhD
#
#        years_experience       industry posting_date application_deadline  \
# 0                     9     Automotive   2024-10-18           2024-11-07
# 1                     1          Media   2024-11-20           2025-01-11
# 2                     2      Education   2025-03-18           2025-04-07
# 3                     7     Consulting   2024-12-23           2025-02-24
# 4                     0          Media   2025-04-15           2025-06-23
# ...                 ...            ...          ...                  ...
# 14995                 1         Energy   2025-02-06           2025-03-25
# 14996                 0     Government   2024-10-16           2024-10-30
# 14997                17  Manufacturing   2024-03-19           2024-05-02
# 14998                 1    Real Estate   2024-03-22           2024-04-23
# 14999                 2     Technology   2024-07-18           2024-08-10
#
#        job_description_length  benefits_score       company_name
# 0                        1076             5.9    Smart Analytics
# 1                        1268             5.2       TechCorp Inc
# 2                        1974             9.4    Autonomous Tech
# 3                        1345             8.6     Future Systems
# 4                        1989             6.6  Advanced Robotics
# ...                       ...             ...                ...
# 14995                    1635             7.9  Advanced Robotics
# 14996                    1624             8.2    Smart Analytics
# 14997                    1336             7.4     AI Innovations
# 14998                    1935             5.6    Smart Analytics
# 14999                    2492             7.6     AI Innovations
#
# [15000 rows x 19 columns]

# %%
#Histogram of salary in USD. Shows how annual AI salaries are distributed
plt.figure(figsize=(10, 6))
sns.histplot(data['salary_usd'], bins=30, kde=True, color='Red')
plt.title('Distribution of Annual Salaries in the AI Market (USD)', fontsize=15)
plt.xlabel('Annual Salary (USD)', fontsize=15)
plt.ylabel('Number of Jobs', fontsize=15)
plt.show()

# %%
#plots a bar chart showing the average salary for each company size
company_size =["S","M","L"]

plt.figure(figsize=(6,6))
company_size =["S","M","L"]
sns.barplot(data=data,x="company_size" ,y="salary_usd" ,palette="viridis")
plt.title("Average Salary by company size" ,fontsize=15)
plt.xlabel("company_size" ,fontsize=12)
plt.ylabel("salary_usd" ,fontsize=12)
plt.show()

# %%
# Plots a boxplot of salaries by education level.
education_required =["Bachelor","Master","Associate","PhD"]

plt.figure(figsize=(10,6))
education_required =["Bachelor","Master","Associate","PhD"]
sns.boxplot(data=data,x="education_required" ,y="salary_usd" ,palette="viridis")
plt.title("Salary Distribution (USD) by education_required" ,fontsize=15)
plt.xlabel("education_required" ,fontsize=12)
plt.ylabel("salary_usd" ,fontsize=12)
plt.show()

# %%
# Plots a bar chart of avaerage salaries by experience level
experience_level=["EN","MI","SE","EX"]

plt.figure(figsize=(10,6))
experience_level=["EN","MI","SE","EX"]
sns.barplot(data=data ,x="experience_level" ,y="salary_usd" ,palette="viridis")
plt.title("Average Salary by experience_level" ,fontsize=15)
plt.xlabel("experience_level" ,fontsize=12)
plt.ylabel("salary_usd" ,fontsize=12)
plt.show()

# %%
#plots a grouped bar chart of average salaries by experience level, separated by education level
experience_level=["EN","MI","SE","EX"]

plt.figure(figsize=(10,6))
experience_level=["EN","MI","SE","EX"]
sns.barplot(data=data ,x="experience_level" ,y="salary_usd" ,hue="education_required" ,palette="viridis")
plt.title("Average Salary by experience_level and education_required" ,fontsize=15)
plt.xlabel("experience_level" ,fontsize=12)
plt.ylabel("salary_usd" ,fontsize=12)
plt.legend(title="education_required")
plt.show()

# %%
#plots a scatter plot showing the relationship between employment type and salary
plt.figure(figsize=(10,6))
sns.scatterplot(data =data ,x="employment_type" ,y="salary_usd" ,color="darkred")
plt.title("Relationship Between employment_type and salary_usd" ,fontsize=15)
plt.xlabel("employment_type" ,fontsize=12)
plt.ylabel("salary_usd" ,fontsize=12)
plt.show()

# %%
#plots a scatter plot showing the relationship between years of experience and salary
plt.figure(figsize=(10, 6))
sns.scatterplot(x='years_experience', y='salary_usd', data=data,color='darkred')
plt.title('Relationship Between Required Years of Experience and Salary', fontsize=15)
plt.xlabel('Required Years of Experience', fontsize=15)
plt.ylabel('Annual Salary (USD)', fontsize=15)
plt.show()
